# %% [markdown]
# ### Perceptron
# 感知机 - 神经网络（深度学习）的起源的算法

# %% [markdown]
# #### 感知机
# 感知机接受多个输入信号，输出一个信号（信号只有 1/0 两种）</br>
# 图2.1是例子:
# * x1、x2是输入信号，y是输出信号，w1、w2是权重。
# * 图中的○称为“神经元”或者“节点”
# * 权重越大，对应该权重的信号的重要性就 越高。
# > 输入信号被送往神经元时，会被分别乘以固定的权重 （w1x1、w2x2）。神经元会计算传送过来的信号的总和，只有当这个总和**超过了某个界限值**时，才会输出1。这也称为“神经元被激活” 。这里将这个界限值称为阈值，用符号θ表示。
#
# $y= \begin{cases} 0 & (w_1x_1+w_2x_2\leqslant\theta) \\ 1 & (w_1x_1+w_2x_2>\theta) & \end{cases}\quad(2.1)$
#
# <img src="data/perceptron/image.png" style="width:50%;">

# %% [markdown]
# #### 简单逻辑电路
# * 与门 AND
# * 与非门 NAND -- Not AND
# * 或门 OR
#
# 3个门电路只有参数的值（权重和阈值）不同</br>
# 相同构造的感知机，只用改变权重w1, w2, θ就可以变成不同的门
# > 相同构造的感知机，只需通过适当地调整参数的值，就可以像“变色龙演员”表演不 同的角色一样，变身为与门、与非门、或门。

# %% [markdown]
# #### 感知机的实现
# 下面代码是与门，只需要把参数取倒数就变成了与非门

# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1 * w1 + x2 * w2
    if(tmp > theta):
        return 1
    elif(tmp <= theta):
        return 0

print(AND(0, 0))
print(AND(0, 1))
print(AND(1, 0))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# #### 导入权重和偏置
# 先把式（2.1）的θ换成−b <br>
# $y= \begin{cases} 0 & (b+w_1x_1+w_2x_2\leqslant0) \\ 1 & (b+w_1x_1+w_2x_2>0) & \end{cases}\quad(2.2)$ <br>
# b称为偏置，w1和w2称为权重。

# %%
import numpy as np
x = np.array([0, 1])
w = np.array([0.5, 0.5])
b = -0.7
print(w * x)
print(np.sum(w * x))
print(np.sum(w * x) + b) # 浮点小数造成的运算误差
# Out:
# [0.  0.5]
# 0.5
# -0.19999999999999996

# %% [markdown]
# #### 使用偏置实现
# 偏置和权重w1 、w2 的作用是不一样的
# * w1 和 w2 是控制输入信号的重要性的参数
# * 而偏置 b 是调整神经元被激活的容易程度（输出信号为1的程度）的参数

# %%
def AND2(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    tmp = np.sum(x * w) + b
    if(tmp > 0):
        return 1
    else:
        return 0
    
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7
    tmp = np.sum(x * w) + b
    if(tmp > 0):
        return 1
    else:
        return 0
    
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(x * w) + b
    if(tmp > 0):
        return 1
    else:
        return 0
    
print(OR(0, 0))
print(OR(0, 1))
print(OR(1, 0))
print(OR(1, 1))
# Out:
# 0
# 1
# 1
# 1

# %% [markdown]
# ### 感知机的局限性
# #### 异或门
# 异或门 XOR gate -- 仅有一个为1的时候才为1 <br>
# 前面介绍的感知机是无法实现这个异或门的。为什么用感知机可以实现与门、或门，却无法实现异或门呢<br>
#
# 或门(三角形代表1，圆形代表0)<br>
# 可以看出只要参数b, w1, w2 <br>
# <img src="data/perceptron/image2.png" style="width:30%;">
#
# 异或门（怎么切分？）<br>
# <img src="data/perceptron/image3.png" style="width:30%;">

# %% [markdown]
# #### 线性非线性
# ○和△无法用一条直线分开，但是如果将“直线”这个限制条 件去掉，就可以实现 <br>
# 感知机的局限性就在于它**只能表示由一条直线分割的空间** <br>
# 图中这样的曲线分割而成的空间称为非线性空间，由直线分割而成的空间称为线性空间 <br>
# <img src="data/perceptron/image4.png" style="width:30%;">

# %% [markdown]
# ### 多层感知机
# 感知机可以“叠加层”来解决上述缺陷问题（通过叠加层来表示异或门是本节的要点）<br>
# #### 门电路组合
# <img src="data/perceptron/image5.png" style="width:40%;"> <br>
# <img src="data/perceptron/image6.png" style="width:40%;">

# %% [markdown]
# #### 多层感知机实现

# %%
def XOR(x1, x2):
    s1 = NAND(x1, x2)
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y

print(XOR(0, 0))
print(XOR(0, 1))
print(XOR(1, 0))
print(XOR(1, 1))
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# 用感知机的表示方法（明确地显示神经元）来表示这个异或门<br>
# 异或门是一种多层结构的神经网络。这里，将最左边的一列称为第0层，中间的一列称为第1层，最右边的一列称为第2层。<br>
# 叠加了多层的感知机也称为**多层感知机**<br>
# <img src="data/perceptron/image7.png" style="width:40%;">
# > 图中的感知机总共由3层构成，但是因为**拥有权重的层实质上只有2层**（第0层和第1层之间，第1层和第2层之间），所以称为“2层感知机”。不过，有的文献认为图的感知机是由3层构成的，因而将其称为“3层感知机”。
#
# 先在第0层和第1层的神经元之间进行信号的传送和接收，然后在第1层和第2层之间进行信号的传送和接收，具体如下所示。
# 1. 第0层的两个神经元接收输入信号，并将信号发送至第1层的神经元。
# 2. 第1层的神经元将信号发送至第2层的神经元，第2层的神经元输出y。

# %% [markdown]
# ### 从与非门到计算机
# 多层感知机可以实现比之前见到的电路更复杂的电路。比如，进行加法运算的加法器也可以用感知机实现。此外，将二进制转换为十进制的编码器、满足某些条件就输出1的电路（用于等价检验的电路）等也可以用感知机表示。实际上，使用感知机甚至可以表示计算机！<br>
# 人们一般会认为计算机内部进行的处理非常复杂，而令人惊讶的是，实际上只需要通过与非门的组合，就能再现计算机进行的处理。<br>
# 理论上可以说2层感知机就能构建计算机。这是因为，已有研究证明，2层感知机（严格地说是**激活函数使用了非线性的sigmoid函数的感知机**，具体请参照下一章）可以表示任意函数。但是，使用2层感知机的构造，通过设定合适的权重来构建计算机是一件非常累人的事情。实际上，在用与非门等低层的元件构建计算机的情况下，分阶段地制作所需的零件（模块）会比较自然，即**先实现与门和或门，然后实现半加器和全加器，接着实现算数逻辑单元（ALU），然后实现CPU**。因此，通过感知机表示计算机时，使用叠加了多层的构造来实现是比较自然的流程。

# %% [markdown]
# ### 小结
# 感知机是一种非常简单的算法，大家应该很快就能理解它的构造。感知机是下一章要学习的神经网络的基础。<br>
# * 感知机是具有输入和输出的算法。给定一个输入后，将输出一个既定的值。
# * 感知机将权重和偏置设定为参数。
# * 使用感知机可以表示与门和或门等逻辑电路。
# * 异或门无法通过单层感知机来表示。
# * 使用2层感知机可以表示异或门。
# * 单层感知机只能表示线性空间，而多层感知机可以表示非线性空间。
# * 多层感知机（在理论上）可以表示计算机。
